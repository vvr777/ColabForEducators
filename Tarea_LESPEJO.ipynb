# %%
import pandas as pd
from google.colab import files

# %%
archivo1 = files.upload()
# Out:
#      <input type="file" id="files-e28e00ee-3e99-4b67-af6a-2028266529c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e28e00ee-3e99-4b67-af6a-2028266529c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
archivo2 = files.upload()
# Out:
#      <input type="file" id="files-373faf55-d16e-4c7f-83b7-85f928edf975" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-373faf55-d16e-4c7f-83b7-85f928edf975">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datos1 = pd.read_excel('students.xls')

# %%
datos2 = pd.read_csv('students.csv')

# %%
# Mostrar las medidas descriptivas de las variables numéricas.
desc_datos1 = datos1.describe()
desc_datos1
# Out:
#        LOCATION CODE  NO. OVERWEIGHT  PCT OVERWEIGHT     NO. OBESE  \
# count    3270.000000     3078.000000     3078.000000   3072.000000
# mean   345142.612844      228.782326        0.166999    247.706706
# std    220310.293245     1914.836525        0.045306   2076.638148
# min         0.000000        5.000000        0.016000      5.000000
# 25%    141501.000000       27.000000        0.144000     29.000000
# 50%    350000.000000       55.000000        0.164000     57.000000
# 75%    572702.000000      114.750000        0.185000    118.000000
# max    700000.000000    77813.000000        1.000000  84578.000000
#
#          PCT OBESE  NO. OVERWEIGHT OR OBESE  PCT OVERWEIGHT OR OBESE  \
# count  3072.000000              3124.000000              3124.000000
# mean      0.184881               468.997119                 0.346345
# std       0.065003              3959.958870                 0.084250
# min       0.013000                 5.000000                 0.036000
# ...

# %%
desc_datos2 = datos2.describe()
desc_datos2
# Out:
#        LOCATION CODE  NO. OVERWEIGHT     NO. OBESE  NO. OVERWEIGHT OR OBESE  \
# count    3270.000000     3078.000000   3072.000000              3124.000000
# mean   345142.612844      228.782326    247.706706               468.997119
# std    220310.293245     1914.836525   2076.638148              3959.958870
# min         0.000000        5.000000      5.000000                 5.000000
# 25%    141501.000000       27.000000     29.000000                55.750000
# 50%    350000.000000       55.000000     57.000000               111.000000
# 75%    572702.000000      114.750000    118.000000               230.000000
# max    700000.000000    77813.000000  84578.000000            162391.000000
#
#            ZIP CODE
# count   3075.000000
# mean   12897.997073
# std     1262.478623
# min     6390.000000
# 25%    11937.000000
# 50%    12953.000000
# 75%    14001.000000
# max    14905.000000

# %%
desc_cuali_datos1 = datos1.describe(include='object')
desc_cuali_datos1
# Out:
#          COUNTY                                        AREA NAME  \
# count      3247                                             3270
# unique       58                                              745
# top     SUFFOLK  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# freq        315                                                6
#
#                        REGION SCHOOL YEARS     GRADE LEVEL        AREA TYPE  \
# count                    3270         3270            3270             3270
# unique                      8            2               3                4
# top     NORTHEASTERN NEW YORK    2010-2012  DISTRICT TOTAL  SCHOOL DISTRICT
# freq                      711         2235            1090             3075
#
#        STREET ADDRESS       CITY STATE  \
# count            3075       3075  3075
# unique            693        636     1
# top      1 ACADEMY ST  ROCHESTER    NY
# freq               12         30  3075
#
# ...

# %%
desc_cuali_datos2 = datos2.describe(include='object')
desc_cuali_datos2
# Out:
#          COUNTY                                        AREA NAME  \
# count      3247                                             3270
# unique       58                                              745
# top     SUFFOLK  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# freq        315                                                6
#
#                        REGION SCHOOL YEARS PCT OVERWEIGHT PCT OBESE  \
# count                    3270         3270           3078      3072
# unique                      8            2            243       322
# top     NORTHEASTERN NEW YORK    2010-2012          16.2%     19.2%
# freq                      711         2235             58        30
#
#        PCT OVERWEIGHT OR OBESE     GRADE LEVEL        AREA TYPE  \
# count                     3124            3270             3270
# unique                     415               3                4
# top                      33.3%  DISTRICT TOTAL  SCHOOL DISTRICT
# ...

# %%
fre_region_datos1 = datos1['REGION'].value_counts()
fre_region_datos1
# Out:
# NORTHEASTERN NEW YORK        711
# NASSAU-SUFFOLK               576
# CENTRAL NEW YORK             549
# HUDSON VALLEY                486
# WESTERN NEW YORK             474
# FINGER LAKES                 342
# NEW YORK - PENN              129
# STATEWIDE (EXCLUDING NYC)      3
# Name: REGION, dtype: int64

# %%
fre_region_datos2 = datos2['REGION'].value_counts()
fre_region_datos2
# Out:
# NORTHEASTERN NEW YORK        711
# NASSAU-SUFFOLK               576
# CENTRAL NEW YORK             549
# HUDSON VALLEY                486
# WESTERN NEW YORK             474
# FINGER LAKES                 342
# NEW YORK - PENN              129
# STATEWIDE (EXCLUDING NYC)      3
# Name: REGION, dtype: int64
